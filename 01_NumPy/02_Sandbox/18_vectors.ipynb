# %%
# distance from origin -> euclidean norm

import numpy as np

# Define an n-dimentional vector A
A = np.array([1, 2, 3, 4, 5, 6])

# Calculate the Euclidean distance from the origin (L2 norm)
distance = np.linalg.norm(A)

print("Euclidean distance from the origin:", distance, "units")
# Out:
# Euclidean distance from the origin: 9.539392014169456 units

# %%
# to find euclidean distance in n-D
import numpy as np

# Define two n-dimentional vectors A and B
A = np.array([1, 2, 3, 4, 5])
B = np.array([6, 7, 8, 9, 10])

# Calculate the difference vector
difference = A - B

# calculate the Euclidean distance between A and B (L2 norm of the difference)
distance = np.linalg.norm(difference)

print("Euclidean distance between A and B:", distance, "units")
# Out:
# Euclidean distance between A and B: 11.180339887498949 units

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from scipy.spatial.distance import euclidean

# 1. Generate 5 random #D Vectors
vectors = np.random.rand(5, 3)

# 2. Assign a random class (0 or 1) to each vector
classes = np.random.randint(0, 2, 5)

# 3. Plot the vectors on a 3D Matplotlib graph
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

for vec, cls in zip(vectors, classes):
    ax.quiver(0, 0, 0, vec[0], vec[1], vec[2], color=("r" if cls == 1 else "b"))

# %%
# 4. Get user input for a query point (3D vector)
import numpy as np

query_vector = np.array(list(map(float, input("Enter the query point (3D vector) separated by space: ").split())))

# %%
# 5. Calculate the distance from the query vector to the 5 vectors and find the nearest neighbor
distances = [euclidean(query_vector, vec) for vec in vectors]
nearest_neighbor_index = np.argmin(distances)

# 6. Output the class of the nearest neighbor
print("The class of the nearest neighbor is:", classes[nearest_neighbor_index])

# Plot the query vector with a different color
ax.quiver(0, 0, 0, query_vector[0], query_vector[1], query_vector[2], color="g")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")

plt.show()
# Out:
# The class of the nearest neighbor is: 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate random 2D data with 100 Points
data = np.random.rand(100, 2)
data
# Out:
# array([[0.12564522, 0.25782635],
#        [0.98558989, 0.55797649],
#        [0.30511674, 0.62482675],
#        [0.68625238, 0.07060628],
#        [0.1173453 , 0.25106344],
#        [0.58582731, 0.46965819],
#        [0.94382059, 0.40699401],
#        [0.96540609, 0.44993122],
#        [0.99439665, 0.33882225],
#        [0.63587432, 0.03498683],
#        [0.37970707, 0.67298556],
#        [0.78269268, 0.36922047],
#        [0.03336014, 0.12186392],
#        [0.2809283 , 0.24030991],
#        [0.44350864, 0.84907679],
#        [0.87650474, 0.59760476],
#        [0.68704913, 0.13630077],
#        [0.34681639, 0.91251977],
#        [0.10383782, 0.28844126],
#        [0.23278052, 0.57562359],
#        [0.61689167, 0.6404667 ],
#        [0.95884364, 0.13955949],
#        [0.49761155, 0.25501715],
#        [0.57179918, 0.63703167],
#        [0.57409337, 0.66880653],
#        [0.56889669, 0.80728884],
#        [0.1675022 , 0.09776587],
#        [0.06986667, 0.24760124],
#        [0.53279189, 0.22462632],
#        [0.89757495, 0.67015346],
#        [0.10331725, 0.32316114],
#        [0.01144194, 0.20274534],
#        [0.06841161, 0.55046953],
#        [0.4347142 , 0.55251217],
#        [0.93576883, 0.41936481],
#        [0.5438306 , 0.38498848],
#        [0.4938016 , 0.29564358],
#        [0.38412052, 0.36484032],
#        [0.8507612 , 0.93185474],
#        [0.98235209, 0.55287742],
#        [0.5649463 , 0.031257  ],
#        [0.44012284, 0.4923063 ],
#        [0.36780107, 0.60655103],
#        [0.26200636, 0.62211439],
#        [0.42890707, 0.26675758],
#        [0.15540917, 0.97059088],
#        [0.16341472, 0.20156482],
#        [0.0869991 , 0.00426435],
#        [0.90629683, 0.54416052],
#        [0.05110325, 0.2949575 ],
#        [0.67103588, 0.27794518],
#        [0.28205805, 0.72244025],
#        [0.13722877, 0.38369733],
#        [0.66529089, 0.36258649],
#        [0.36648515, 0.43317785],
#        [0.35750953, 0.11061349],
#        [0.89398168, 0.7179948 ],
#        [0.59299153, 0.12768519],
#        [0.99023139, 0.83169661],
#        [0.4682166 , 0.60357008],
#        [0.33111423, 0.17049679],
#        [0.99217256, 0.4572547 ],
#        [0.12217865, 0.89505707],
#        [0.57628774, 0.08038711],
#        [0.06287848, 0.09652426],
#        [0.80647798, 0.5897445 ],
#        [0.51502574, 0.57861248],
#        [0.3397168 , 0.36090633],
#        [0.06398534, 0.77300168],
#        [0.5950931 , 0.89701451],
#        [0.21466779, 0.71397867],
#        [0.7065232 , 0.65313383],
#        [0.78835639, 0.21248377],
#        [0.0804895 , 0.11883105],
#        [0.74838356, 0.04531153],
#        [0.85675382, 0.75075303],
#        [0.0768207 , 0.51437675],
#        [0.22677515, 0.47871686],
#        [0.4643015 , 0.03815609],
#        [0.21237387, 0.82252622],
#        [0.9703977 , 0.30772725],
#        [0.01464816, 0.2214769 ],
#        [0.38486516, 0.14413849],
#        [0.88998201, 0.10289452],
#        [0.1545816 , 0.38250284],
#        [0.39979497, 0.18618489],
#        [0.00766999, 0.51652812],
#        [0.07507244, 0.12152787],
#        [0.83548468, 0.50587961],
#        [0.17334732, 0.62929063],
#        [0.37553943, 0.3517212 ],
#        [0.16963436, 0.07886158],
#        [0.54362859, 0.46348429],
#        [0.40925305, 0.39598875],
#        [0.59475292, 0.63333832],
#        [0.78574726, 0.39166914],
#        [0.16767653, 0.55935366],
#        [0.13856707, 0.2035409 ],
#        [0.9329828 , 0.91601732],
#        [0.89804776, 0.97246952]])

# %%
# Plot the original data
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[:, 0], data[:, 1])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Before Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
# Out:
# C:\Users\loken\AppData\Local\Temp\ipykernel_14800\113537970.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Calculate the mean of the data along each dimension
data_mean = np.mean(data, axis=0)

print(data_mean)
# Perform mean centering
centered_data = data - data_mean
# Out:
# [0.47330938 0.43131208]

# %%
# Plot the mean-centered data
plt.subplot(1, 2, 2)
plt.scatter(centered_data[:, 0], centered_data[:, 1], color="orange")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("After Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()
# Out:
# C:\Users\loken\AppData\Local\Temp\ipykernel_14800\3230349002.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate random 2D data with 100 Points
data = np.random.rand(100, 2)

# Plot the original data
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[:, 0], data[:, 1])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Before Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# Calculate the mean of the data along each dimension
data_mean = np.mean(data, axis=0)

print(data_mean)
# Perform mean centering
centered_data = data - data_mean

# Plot the mean-centered data
plt.subplot(1, 2, 2)
plt.scatter(centered_data[:, 0], centered_data[:, 1], color="orange")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("After Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()
# Out:
# C:\Users\loken\AppData\Local\Temp\ipykernel_14800\1787272410.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\loken\AppData\Local\Temp\ipykernel_14800\1787272410.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# [0.50792988 0.4995085 ]

# %%
import numpy as np

# define two vectors
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

print(np.dot(A, B))
print(A@B)
# Out:
# 32
# 32

# %%
import numpy as np

# Define three vectors
# define three vectors
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
C = np.array([7, 8, 9])

# Calculate dot product using numpy.dot() function
dot_product_AB = np.dot(A, B)
dot_product_BA = np.dot(B, A)

print(dot_product_AB)
print(dot_product_BA)

# Check commutative property: A + B = B + A
if dot_product_AB == dot_product_BA:
    print("The dot product is cummutative.")
else:
    print("The dot product is not commutative.")
# Out:
# 32
# 32
# The dot product is cummutative.

# %%
# Check distributive property: A * (B + C) = A * B + A * C
dot_product_A_BC = np.dot(A, B + C)
dot_product_AB_plus_AC = np.dot(A, B) + np.dot(A, C)

print(dot_product_A_BC)
print(dot_product_AB_plus_AC)

if dot_product_A_BC == dot_product_AB_plus_AC:
    print("The dot product is distributive.")
else:
    print("The dot product is not distributive.")
# Out:
# 82
# 82
# The dot product is distributive.

# %%
import numpy as np

# Define three vectors
A = np.array([1, 2, 3])
B = np.array([-4, -5, -6])
C = np.array([5, 5, 5])

# Calculate the cosine similarity
cosine_similarity = np.dot(A, B) / (np.linalg.norm(A) * np.linalg.norm(B))

print("Cosine similarity between A and B:", cosine_similarity)

# Calculate the cosine similarity
cosine_similarity = np.dot(A, C) / (np.linalg.norm(A) * np.linalg.norm(C))

print("Cosine similarity between A and C:", cosine_similarity)
# Out:
# Cosine similarity between A and B: -0.9746318461970762
# Cosine similarity between A and C: 0.9258200997725513
